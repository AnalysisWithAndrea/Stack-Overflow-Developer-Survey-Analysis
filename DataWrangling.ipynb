# %% [markdown]
# # **Data Wrangling**

# %% [markdown]
# <hr>

# %%
import pandas as pd

# %% [markdown]
# Load the dataset into a dataframe.

# %%
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m1_survey_data.csv")

# %% [markdown]
# ## Finding duplicates

# %% [markdown]
# Finding the number of duplicate rows that exist in the dataframe.

# %%
df.duplicated().sum()
# Out:
# 154

# %% [markdown]
# ## Removing duplicates

# %% [markdown]
# Remove the duplicate rows from the dataframe.

# %%
df = df.drop_duplicates()
len(df)
# Out:
# 11398

# %% [markdown]
# Verifying if duplicates were actually dropped.

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Finding Missing values

# %%
df.isnull().sum()
# Out:
# Respondent        0
# MainBranch        0
# Hobbyist          0
# OpenSourcer       0
# OpenSource       81
#                ...
# Sexuality       542
# Ethnicity       675
# Dependents      140
# SurveyLength     19
# SurveyEase       14
# Length: 85, dtype: int64

# %% [markdown]
# ## Imputing missing values

# %% [markdown]
# Finding the  value counts for the column WorkLoc.

# %%
df['WorkLoc'].value_counts()
# Out:
# Office                                            6806
# Home                                              3589
# Other place, such as a coworking space or cafe     971
# Name: WorkLoc, dtype: int64

# %%
df['WorkLoc'].isnull().sum()
# Out:
# 32

# %%
mode = df['WorkLoc'].mode()[0]
mode
# Out:
# 'Office'

# %% [markdown]
# Imputing all the empty rows in the column WorkLoc with the majority.

# %%
df['WorkLoc'] = df['WorkLoc'].fillna(mode)

# %% [markdown]
# After imputation there should ideally not be any empty rows in the WorkLoc column.

# %% [markdown]
# Verify if imputing was successful.

# %%
df['WorkLoc'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ## Normalizing data

# %% [markdown]
# There are two columns in the dataset that talk about compensation.
#
# One is "CompFreq". This column shows how often a developer is paid (Yearly, Monthly, Weekly).
#
# The other is "CompTotal". This column talks about how much the developer is paid per Year, Month, or Week depending upon his/her "CompFreq".
#
# This makes it difficult to compare the total compensation of the developers.
#
# In this section I created a new column called 'NormalizedAnnualCompensation' which contains the 'Annual Compensation' irrespective of the 'CompFreq'.
#
# This new column makes comparison of salaries easy.

# %% [markdown]
# <hr>

# %%
comp = df['CompFreq'].unique()
comp
# Out:
#                               Respondent                      MainBranch  \
# 0                                61000.0                         61000.0
# 1                               138000.0                        138000.0
# 2                                90000.0                         90000.0
# 3                                   16.0  I am a developer by profession
# 4                                90000.0                         90000.0
# ...                                  ...                             ...
# 11548                            20000.0                         20000.0
# 11549                            32000.0                         32000.0
# 11550                           210000.0                        210000.0
# 11551                            25142.0  I am a developer by profession
# NormalizedAnnualCompensation         NaN                             NaN
#
#                               Hobbyist  \
# 0                              61000.0
# 1                             138000.0
# 2                              90000.0
# 3                                  Yes
# 4                              90000.0
# ...                                ...
# 11548                          20000.0
# 11549                          32000.0
# 11550                         210000.0
# 11551                              Yes
# NormalizedAnnualCompensation       NaN
#
#                                                                     OpenSourcer  \
# 0                                                                       61000.0
# 1                                                                      138000.0
# 2                                                                       90000.0
# 3                                                                         Never
# 4                                                                       90000.0
# ...                                                                         ...
# 11548                                                                   20000.0
# 11549                                                                   32000.0
# 11550                                                                  210000.0
# 11551                         Less than once a month but more than once per ...
# NormalizedAnnualCompensation                                                NaN
#
#                                                                      OpenSource  \
# 0                                                                       61000.0
# 1                                                                      138000.0
# 2                                                                       90000.0
# 3                             The quality of OSS and closed source software ...
# 4                                                                       90000.0
# ...                                                                         ...
# 11548                                                                   20000.0
# 11549                                                                   32000.0
# 11550                                                                  210000.0
# 11551                         OSS is, on average, of HIGHER quality than pro...
# NormalizedAnnualCompensation                                                NaN
#
#                                       Employment         Country   Student  \
# 0                                        61000.0         61000.0   61000.0
# 1                                       138000.0        138000.0  138000.0
# 2                                        90000.0         90000.0   90000.0
# 3                             Employed full-time  United Kingdom        No
# 4                                        90000.0         90000.0   90000.0
# ...                                          ...             ...       ...
# 11548                                    20000.0         20000.0   20000.0
# 11549                                    32000.0         32000.0   32000.0
# 11550                                   210000.0        210000.0  210000.0
# 11551                         Employed full-time  United Kingdom        No
# NormalizedAnnualCompensation                 NaN             NaN       NaN
#
#                                                                   EdLevel  \
# 0                                                                 61000.0
# 1                                                                138000.0
# 2                                                                 90000.0
# 3                             Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 4                                                                 90000.0
# ...                                                                   ...
# 11548                                                             20000.0
# 11549                                                             32000.0
# 11550                                                            210000.0
# 11551                           Other doctoral degree (Ph.D, Ed.D., etc.)
# NormalizedAnnualCompensation                                          NaN
#
#                                                                  UndergradMajor  \
# 0                                                                       61000.0
# 1                                                                      138000.0
# 2                                                                       90000.0
# 3                                                                           NaN
# 4                                                                       90000.0
# ...                                                                         ...
# 11548                                                                   20000.0
# 11549                                                                   32000.0
# 11550                                                                  210000.0
# 11551                         A natural science (ex. biology, chemistry, phy...
# NormalizedAnnualCompensation                                                NaN
#
#                               ...     11505     11513     11516     11518  \
# 0                             ...       NaN       NaN       NaN       NaN
# 1                             ...       NaN       NaN       NaN       NaN
# 2                             ...       NaN       NaN       NaN       NaN
# 3                             ...       NaN       NaN       NaN       NaN
# 4                             ...       NaN       NaN       NaN       NaN
# ...                           ...       ...       ...       ...       ...
# 11548                         ...       NaN       NaN       NaN       NaN
# 11549                         ...       NaN       NaN       NaN       NaN
# 11550                         ...       NaN       NaN       NaN       NaN
# 11551                         ...       NaN       NaN       NaN       NaN
# NormalizedAnnualCompensation  ...  140000.0  111600.0  456000.0  650000.0
#
#                                  11525    11526      11536    11537    11538  \
# 0                                  NaN      NaN        NaN      NaN      NaN
# 1                                  NaN      NaN        NaN      NaN      NaN
# 2                                  NaN      NaN        NaN      NaN      NaN
# 3                                  NaN      NaN        NaN      NaN      NaN
# 4                                  NaN      NaN        NaN      NaN      NaN
# ...                                ...      ...        ...      ...      ...
# 11548                              NaN      NaN        NaN      NaN      NaN
# 11549                              NaN      NaN        NaN      NaN      NaN
# 11550                              NaN      NaN        NaN      NaN      NaN
# 11551                              NaN      NaN        NaN      NaN      NaN
# NormalizedAnnualCompensation  110000.0  67000.0  1250000.0  79000.0  80000.0
#
#                                  11542
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ...                                ...
# 11548                              NaN
# 11549                              NaN
# 11550                              NaN
# 11551                              NaN
# NormalizedAnnualCompensation  552000.0
#
# [11399 rows x 2672 columns]

# %% [markdown]
# Creating a new column named 'NormalizedAnnualCompensation'

# %%
df['NormalizedAnnualCompensation'] = pd.Series(dtype='float64')
for index,row in df.iterrows():
    if row['CompFreq'] == comp[0]:
        row['NormalizedAnnualCompensation'] = row['CompTotal']
        df.loc[index, 'NormalizedAnnualCompensation'] = row['CompTotal']
    elif row['CompFreq'] == comp[1]:
        row['NormalizedAnnualCompensation'] = row['CompTotal']*12
    elif row['CompFreq'] == comp[2]:
        row['NormalizedAnnualCompensation'] = row['CompTotal']*52
        
df['NormalizedAnnualCompensation'].median()
df
# Out:
#                               Respondent                      MainBranch  \
# 0                                61000.0                         61000.0
# 1                               138000.0                        138000.0
# 2                                90000.0                         90000.0
# 3                                   16.0  I am a developer by profession
# 4                                90000.0                         90000.0
# ...                                  ...                             ...
# 11548                            20000.0                         20000.0
# 11549                            32000.0                         32000.0
# 11550                           210000.0                        210000.0
# 11551                            25142.0  I am a developer by profession
# NormalizedAnnualCompensation         NaN                             NaN
#
#                               Hobbyist  \
# 0                              61000.0
# 1                             138000.0
# 2                              90000.0
# 3                                  Yes
# 4                              90000.0
# ...                                ...
# 11548                          20000.0
# 11549                          32000.0
# 11550                         210000.0
# 11551                              Yes
# NormalizedAnnualCompensation       NaN
#
#                                                                     OpenSourcer  \
# 0                                                                       61000.0
# 1                                                                      138000.0
# 2                                                                       90000.0
# 3                                                                         Never
# 4                                                                       90000.0
# ...                                                                         ...
# 11548                                                                   20000.0
# 11549                                                                   32000.0
# 11550                                                                  210000.0
# 11551                         Less than once a month but more than once per ...
# NormalizedAnnualCompensation                                                NaN
#
#                                                                      OpenSource  \
# 0                                                                       61000.0
# 1                                                                      138000.0
# 2                                                                       90000.0
# 3                             The quality of OSS and closed source software ...
# 4                                                                       90000.0
# ...                                                                         ...
# 11548                                                                   20000.0
# 11549                                                                   32000.0
# 11550                                                                  210000.0
# 11551                         OSS is, on average, of HIGHER quality than pro...
# NormalizedAnnualCompensation                                                NaN
#
#                                       Employment         Country   Student  \
# 0                                        61000.0         61000.0   61000.0
# 1                                       138000.0        138000.0  138000.0
# 2                                        90000.0         90000.0   90000.0
# 3                             Employed full-time  United Kingdom        No
# 4                                        90000.0         90000.0   90000.0
# ...                                          ...             ...       ...
# 11548                                    20000.0         20000.0   20000.0
# 11549                                    32000.0         32000.0   32000.0
# 11550                                   210000.0        210000.0  210000.0
# 11551                         Employed full-time  United Kingdom        No
# NormalizedAnnualCompensation                 NaN             NaN       NaN
#
#                                                                   EdLevel  \
# 0                                                                 61000.0
# 1                                                                138000.0
# 2                                                                 90000.0
# 3                             Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 4                                                                 90000.0
# ...                                                                   ...
# 11548                                                             20000.0
# 11549                                                             32000.0
# 11550                                                            210000.0
# 11551                           Other doctoral degree (Ph.D, Ed.D., etc.)
# NormalizedAnnualCompensation                                          NaN
#
#                                                                  UndergradMajor  \
# 0                                                                       61000.0
# 1                                                                      138000.0
# 2                                                                       90000.0
# 3                                                                           NaN
# 4                                                                       90000.0
# ...                                                                         ...
# 11548                                                                   20000.0
# 11549                                                                   32000.0
# 11550                                                                  210000.0
# 11551                         A natural science (ex. biology, chemistry, phy...
# NormalizedAnnualCompensation                                                NaN
#
#                               ...     11505     11513     11516     11518  \
# 0                             ...       NaN       NaN       NaN       NaN
# 1                             ...       NaN       NaN       NaN       NaN
# 2                             ...       NaN       NaN       NaN       NaN
# 3                             ...       NaN       NaN       NaN       NaN
# 4                             ...       NaN       NaN       NaN       NaN
# ...                           ...       ...       ...       ...       ...
# 11548                         ...       NaN       NaN       NaN       NaN
# 11549                         ...       NaN       NaN       NaN       NaN
# 11550                         ...       NaN       NaN       NaN       NaN
# 11551                         ...       NaN       NaN       NaN       NaN
# NormalizedAnnualCompensation  ...  140000.0  111600.0  456000.0  650000.0
#
#                                  11525    11526      11536    11537    11538  \
# 0                                  NaN      NaN        NaN      NaN      NaN
# 1                                  NaN      NaN        NaN      NaN      NaN
# 2                                  NaN      NaN        NaN      NaN      NaN
# 3                                  NaN      NaN        NaN      NaN      NaN
# 4                                  NaN      NaN        NaN      NaN      NaN
# ...                                ...      ...        ...      ...      ...
# 11548                              NaN      NaN        NaN      NaN      NaN
# 11549                              NaN      NaN        NaN      NaN      NaN
# 11550                              NaN      NaN        NaN      NaN      NaN
# 11551                              NaN      NaN        NaN      NaN      NaN
# NormalizedAnnualCompensation  110000.0  67000.0  1250000.0  79000.0  80000.0
#
#                                  11542
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ...                                ...
# 11548                              NaN
# 11549                              NaN
# 11550                              NaN
# 11551                              NaN
# NormalizedAnnualCompensation  552000.0
#
# [11399 rows x 2672 columns]
